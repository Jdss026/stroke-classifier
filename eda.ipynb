# %% [markdown]
# # Stroke prediction

# %% [markdown]
# Análise exploratória do dataset contendo informações médicas e condições de pacientes em que alguns sofreram AVC. Iremos verificar o dataset a fim de relacionar tais condições com a possibilidade do paciente sofre um derrame cerebral.

# %% [markdown]
# Importando as bibliotecas

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Importando o dataset

# %%
df = pd.read_csv('dataset.csv')
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0  30669    Male   3.0             0              0           No
# 1  30468    Male  58.0             1              0          Yes
# 2  16523  Female   8.0             0              0           No
# 3  56543  Female  70.0             0              0          Yes
# 4  46136    Male  14.0             0              0           No
#
#       work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0      children          Rural              95.12  18.0              NaN
# 1       Private          Urban              87.96  39.2     never smoked
# 2       Private          Urban             110.89  17.6              NaN
# 3       Private          Rural              69.04  35.9  formerly smoked
# 4  Never_worked          Rural             161.28  19.1              NaN
#
#    stroke
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.shape
# Out:
# (43400, 12)

# %% [markdown]
# O dataset contém 43k+ informações médicas de pacientes identificados por Id.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43400 entries, 0 to 43399
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 43400 non-null  int64
#  1   gender             43400 non-null  object
#  2   age                43400 non-null  float64
#  3   hypertension       43400 non-null  int64
#  4   heart_disease      43400 non-null  int64
#  5   ever_married       43400 non-null  object
#  6   work_type          43400 non-null  object
#  7   Residence_type     43400 non-null  object
#  8   avg_glucose_level  43400 non-null  float64
#  9   bmi                41938 non-null  float64
#  10  smoking_status     30108 non-null  object
#  11  stroke             43400 non-null  int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 4.0+ MB

# %% [markdown]
# Quantos destes valores são de stroke(avc) percentualmente?

# %%
df['stroke'].sum()/df.shape[0] * 100
# Out:
# 1.804147465437788

# %% [markdown]
# O dataset contém algumas colunas com itens objeto, para fins de classificação devemos transformar em tipo numérico. Itens nulos nas colunas bmi e smoking_status. Iremos verificar por valores unicos e quais são estes valores

# %%
df.nunique()
# Out:
# id                   43400
# gender                   3
# age                    104
# hypertension             2
# heart_disease            2
# ever_married             2
# work_type                5
# Residence_type           2
# avg_glucose_level    12543
# bmi                    555
# smoking_status           3
# stroke                   2
# dtype: int64

# %%
for cols in df.columns:
    if df[cols].nunique() >= 2 and df[cols].nunique() < 10 :
        print(cols,df[cols].unique())
# Out:
# gender ['Male' 'Female' 'Other']
# hypertension [0 1]
# heart_disease [0 1]
# ever_married ['No' 'Yes']
# work_type ['children' 'Private' 'Never_worked' 'Self-employed' 'Govt_job']
# Residence_type ['Rural' 'Urban']
# smoking_status [nan 'never smoked' 'formerly smoked' 'smokes']
# stroke [0 1]

# %% [markdown]
# Mapeando os valores do tipo objeto com valores numericos

# %%
df['gender'] = df['gender'].replace({'Male': 0, 'Female': 1, 'Other': 2})
df['ever_married'] = df['ever_married'].replace({'No': 0, 'Yes': 1})
df['Residence_type'] = df['Residence_type'].replace({'Rural': 0, 'Urban': 1})

df.head()
# Out:
#       id  gender   age  hypertension  heart_disease  ever_married  \
# 0  30669       0   3.0             0              0             0
# 1  30468       0  58.0             1              0             1
# 2  16523       1   8.0             0              0             0
# 3  56543       1  70.0             0              0             1
# 4  46136       0  14.0             0              0             0
#
#       work_type  Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0      children               0              95.12  18.0              NaN
# 1       Private               1              87.96  39.2     never smoked
# 2       Private               1             110.89  17.6              NaN
# 3       Private               0              69.04  35.9  formerly smoked
# 4  Never_worked               0             161.28  19.1              NaN
#
#    stroke
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.describe()
# Out:
#                  id        gender           age  hypertension  heart_disease  \
# count  43400.000000  43400.000000  43400.000000  43400.000000   43400.000000
# mean   36326.142350      0.591866     42.217894      0.093571       0.047512
# std    21072.134879      0.492009     22.519649      0.291235       0.212733
# min        1.000000      0.000000      0.080000      0.000000       0.000000
# 25%    18038.500000      0.000000     24.000000      0.000000       0.000000
# 50%    36351.500000      1.000000     44.000000      0.000000       0.000000
# 75%    54514.250000      1.000000     60.000000      0.000000       0.000000
# max    72943.000000      2.000000     82.000000      1.000000       1.000000
#
#        ever_married  Residence_type  avg_glucose_level           bmi  \
# count  43400.000000    43400.000000       43400.000000  41938.000000
# mean       0.643733        0.501290         104.482750     28.605038
# std        0.478901        0.500004          43.111751      7.770020
# min        0.000000        0.000000          55.000000     10.100000
# 25%        0.000000        0.000000          77.540000     23.200000
# 50%        1.000000        1.000000          91.580000     27.700000
# 75%        1.000000        1.000000         112.070000     32.900000
# max        1.000000        1.000000         291.050000     97.600000
#
#              stroke
# count  43400.000000
# mean       0.018041
# std        0.133103
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
df.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'id'}>,
#         <AxesSubplot:title={'center':'gender'}>,
#         <AxesSubplot:title={'center':'age'}>],
#        [<AxesSubplot:title={'center':'hypertension'}>,
#         <AxesSubplot:title={'center':'heart_disease'}>,
#         <AxesSubplot:title={'center':'ever_married'}>],
#        [<AxesSubplot:title={'center':'Residence_type'}>,
#         <AxesSubplot:title={'center':'avg_glucose_level'}>,
#         <AxesSubplot:title={'center':'bmi'}>],
#        [<AxesSubplot:title={'center':'stroke'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# verificando a porcentagem de valores nulos nas colunas

# %%
missing_perc = (df.isnull().sum()/ df.shape[0])*100
missing_perc
# Out:
# id                    0.000000
# gender                0.000000
# age                   0.000000
# hypertension          0.000000
# heart_disease         0.000000
# ever_married          0.000000
# work_type             0.000000
# Residence_type        0.000000
# avg_glucose_level     0.000000
# bmi                   3.368664
# smoking_status       30.626728
# stroke                0.000000
# dtype: float64

# %% [markdown]
# Substituimos os valores nulos de smoking_status pela moda dos valores não nulos

# %%
mode_smoking = df['smoking_status'].mode()[0]
df['smoking_status'].fillna(mode_smoking, inplace=True)

# %% [markdown]
# Iremos trocar os valores de bmi pela moda

# %%
mode_bmi = df['bmi'].mode()[0]
df['bmi'].fillna(mode_bmi, inplace=True)

# %% [markdown]
# Verificamos se há valores nulos

# %%
missing_perc = (df.isnull().sum()/ df.shape[0])*100
missing_perc
# Out:
# id                   0.0
# gender               0.0
# age                  0.0
# hypertension         0.0
# heart_disease        0.0
# ever_married         0.0
# work_type            0.0
# Residence_type       0.0
# avg_glucose_level    0.0
# bmi                  0.0
# smoking_status       0.0
# stroke               0.0
# dtype: float64

# %%
df.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'id'}>,
#         <AxesSubplot:title={'center':'gender'}>,
#         <AxesSubplot:title={'center':'age'}>],
#        [<AxesSubplot:title={'center':'hypertension'}>,
#         <AxesSubplot:title={'center':'heart_disease'}>,
#         <AxesSubplot:title={'center':'ever_married'}>],
#        [<AxesSubplot:title={'center':'Residence_type'}>,
#         <AxesSubplot:title={'center':'avg_glucose_level'}>,
#         <AxesSubplot:title={'center':'bmi'}>],
#        [<AxesSubplot:title={'center':'stroke'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# verificamos que o histograma da idade está confuso. Para verificar.

# %%
df['age'].hist(bins = 50)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(13, 8))
corr= df.corr()

# Plot do triangulo superior da matriz de correlação
matrix = np.triu(corr)

# usando a matriz superior como uma mascara
sns.heatmap(corr, annot=True, mask=matrix)
plt.show()

# %% [markdown]
# O mapa mostra uma alta correlação entre idade e casamento

# %%
X = df.drop(['stroke'], axis=1)
y = df['stroke']

# %%
y.value_counts()
# Out:
# 0    42617
# 1      783
# Name: stroke, dtype: int64

# %%
y.value_counts().plot.pie(autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='stroke'>

# %%
# Out:
#           id  gender   age  hypertension  heart_disease  ever_married  \
# 0      30669       0   3.0             0              0             0
# 1      30468       0  58.0             1              0             1
# 2      16523       1   8.0             0              0             0
# 3      56543       1  70.0             0              0             1
# 4      46136       0  14.0             0              0             0
# ...      ...     ...   ...           ...            ...           ...
# 43395  56196       1  10.0             0              0             0
# 43396   5450       1  56.0             0              0             1
# 43397  28375       1  82.0             1              0             1
# 43398  27973       0  40.0             0              0             1
# 43399  36271       1  82.0             0              0             1
#
#           work_type  Residence_type  avg_glucose_level   bmi   smoking_status
# 0          children               0              95.12  18.0     never smoked
# 1           Private               1              87.96  39.2     never smoked
# 2           Private               1             110.89  17.6     never smoked
# 3           Private               0              69.04  35.9  formerly smoked
# 4      Never_worked               0             161.28  19.1     never smoked
# ...             ...             ...                ...   ...              ...
# 43395      children               1              58.64  20.4     never smoked
# 43396      Govt_job               1             213.61  55.4  formerly smoked
# 43397       Private               1              91.94  28.9  formerly smoked
# 43398       Private               1              99.16  33.2     never smoked
# 43399       Private               1              79.48  20.6     never smoked
#
# [43400 rows x 11 columns]
